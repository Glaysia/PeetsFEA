# %%
from PeetsFEA.peetspareto.litzpcb import run_litzpcb_nsga2

# %%
run_litzpcb_nsga2(show_plot=True)
# Out:
# ...
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ...
#      1 |      100 |      1 |  1.138612E+03 |  8.854156E+04 |             - |             -
#      2 |      200 |      1 |  9.965557E+02 |  1.535166E+04 |             - |             -
#      3 |      300 |      1 |  9.664554E+02 |  6.092151E+03 |             - |             -
#      4 |      400 |      1 |  2.882385E+01 |  2.636431E+03 |             - |             -
#      5 |      500 |      1 |  2.882385E+01 |  1.437748E+03 |             - |             -
#      6 |      600 |      1 |  1.126714E+01 |  8.312293E+02 |             - |             -
#      7 |      700 |      1 |  8.3135756116 |  4.643892E+02 |             - |             -
#      8 |      800 |      1 |  5.8936807317 |  1.545044E+02 |             - |             -
#      9 |      900 |      1 |  5.8936807317 |  3.945009E+01 |             - |             -
# ...
